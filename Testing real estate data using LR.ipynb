# %%
import pandas as pd
data1=pd.read_excel("Real estate valuation data set.xlsx")

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
data1
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1          2012.916667          32.0
# 1      2          2012.916667          19.5
# 2      3          2013.583333          13.3
# 3      4          2013.500000          13.3
# 4      5          2012.833333           5.0
# ..   ...                  ...           ...
# 409  410          2013.000000          13.7
# 410  411          2012.666667           5.6
# 411  412          2013.250000          18.8
# 412  413          2013.000000           8.1
# 413  414          2013.500000           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
X = data1.drop('Y house price of unit area', axis=1)
y = data1['Y house price of unit area']

# %%
y
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: Y house price of unit area, Length: 414, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.10, shuffle=False)

# %%
type(x_train)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
type(x_test)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
x_train
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1          2012.916667          32.0
# 1      2          2012.916667          19.5
# 2      3          2013.583333          13.3
# 3      4          2013.500000          13.3
# 4      5          2012.833333           5.0
# ..   ...                  ...           ...
# 367  368          2012.833333          15.0
# 368  369          2013.416667          18.2
# 369  370          2012.666667          20.2
# 370  371          2012.750000          15.9
# 371  372          2013.500000           4.1
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
y_train
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 367    20.9
# 368    43.1
# 369    22.8
# 370    42.1
# 371    51.7
# Name: Y house price of unit area, Length: 372, dtype: float64

# %%
x_test
# Out:
#       No  X1 transaction date  X2 house age  \
# 372  373          2013.000000          33.9
# 373  374          2013.083333           0.0
# 374  375          2013.250000           5.4
# 375  376          2013.250000          21.7
# 376  377          2013.416667          14.7
# 377  378          2013.333333           3.9
# 378  379          2013.333333          37.3
# 379  380          2013.333333           0.0
# 380  381          2013.333333          14.1
# 381  382          2013.416667           8.0
# 382  383          2013.000000          16.3
# 383  384          2012.666667          29.1
# 384  385          2012.750000          16.1
# 385  386          2013.000000          18.3
# 386  387          2012.833333           0.0
# 387  388          2013.250000          16.2
# 388  389          2013.500000          10.4
# 389  390          2013.250000          40.9
# 390  391          2013.500000          32.8
# 391  392          2013.583333           6.2
# ...

# %%
y_test
# Out:
# 372    41.5
# 373    52.2
# 374    49.5
# 375    23.8
# 376    30.5
# 377    56.8
# 378    37.4
# 379    69.7
# 380    53.3
# 381    47.3
# 382    29.3
# 383    40.3
# 384    12.9
# 385    46.6
# 386    55.3
# 387    25.6
# 388    27.3
# 389    67.7
# 390    38.6
# 391    31.3
# 392    35.3
# 393    40.3
# 394    24.7
# 395    42.5
# 396    31.9
# 397    32.2
# 398    23.0
# 399    37.3
# 400    35.5
# 401    27.7
# 402    28.5
# 403    39.7
# 404    41.2
# 405    37.2
# 406    40.5
# 407    22.3
# 408    28.1
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: Y house price of unit area, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train, y_train) # train the model to set its parameter values and thereby make the model1 "trained"
# Out:
# LinearRegression()

# %%
r_square = model.score(x_train, y_train) # coefficient of determination R^2 indicates correlation between features and target
print('coefficient of determination:', r_square) 
print('intercept:', model.intercept_)
print('coefficients:', model.coef_)
# Out:
# coefficient of determination: 0.5834495693395754
# intercept: -15141.68958829468
# coefficients: [-4.91004069e-03  5.27151664e+00 -2.73344324e-01 -4.34998913e-03
#   1.12111795e+00  2.52016286e+02 -1.41476738e+01]

# %%
y_pred = model.predict(x_test) # test step in sklearn
y_pred.reshape((-1,1))
# Out:
# array([[38.31098419],
#        [43.08669093],
#        [47.44569403],
#        [29.46731505],
#        [33.25043252],
#        [47.90089036],
#        [39.42830535],
#        [50.36551908],
#        [46.57363082],
#        [54.13320597],
#        [12.303155  ],
#        [36.04296092],
#        [11.61861123],
#        [50.43746816],
#        [40.02104203],
#        [30.35405696],
#        [33.52928379],
#        [39.22417896],
#        [43.73955785],
#        [30.50466983],
#        [37.19982234],
#        [41.73550353],
#        [15.0743348 ],
#        [38.31852755],
#        [26.83791971],
#        [44.80819329],
#        [33.14241163],
#        [38.79678501],
#        [39.85132228],
#        [32.13880581],
#        [38.31054158],
#        [43.82482532],
#        [45.8270979 ],
#        [35.99489156],
#        [48.53638885],
#        [25.26250297],
#        [30.94360938],
#        [13.0392734 ],
#        [48.64981166],
#        [45.84305947],
#        [43.28846631],
# ...
